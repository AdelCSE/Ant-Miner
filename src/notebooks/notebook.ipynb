# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv('/home/adel/Documents/Code/Ant-Miner/datasets/c4.csv')

# %%
df.shape
# Out:
# (376640, 43)

# %%
df.dtypes
# Out:
# pos_01    float64
# pos_02    float64
# pos_03    float64
# pos_04    float64
# pos_05    float64
# pos_06    float64
# pos_07    float64
# pos_08    float64
# pos_09    float64
# pos_10    float64
# pos_11    float64
# pos_12    float64
# pos_13    float64
# pos_14    float64
# pos_15    float64
# pos_16    float64
# pos_17    float64
# pos_18    float64
# pos_19    float64
# pos_20    float64
# pos_21    float64
# pos_22    float64
# pos_23    float64
# pos_24    float64
# pos_25    float64
# pos_26    float64
# pos_27    float64
# pos_28    float64
# pos_29    float64
# pos_30    float64
# pos_31    float64
# pos_32    float64
# pos_33    float64
# pos_34    float64
# pos_35    float64
# pos_36    float64
# pos_37    float64
# pos_38    float64
# pos_39    float64
# pos_40    float64
# pos_41    float64
# pos_42    float64
# winner    float64
# dtype: object

# %%
missing_values = df.isnull().sum()
missing_values[missing_values > 0]
# Out:
# winner    21
# dtype: int64

# %%
# transform each column to categorical
for col in df.columns:
    df[col] = df[col].astype(str)

# %%
df.dtypes
# Out:
# age             object
# mefalsepause    object
# tumor-size      object
# inv-falsedes    object
# falsede-caps    object
# deg-malig       object
# breast          object
# breast-quad     object
# irradiat        object
# class           object
# dtype: object

# %%
# save the transformed dataset
df.to_csv('/home/adel/Documents/Code/Ant-Miner/datasets/lj.csv', index=False)

# %%
df = pd.read_csv('/home/adel/Documents/Code/Ant-Miner/datasets/lj.csv')

# %%
df.dtypes
# Out:
# age             object
# mefalsepause    object
# tumor-size      object
# inv-falsedes    object
# falsede-caps      bool
# deg-malig        int64
# breast          object
# breast-quad     object
# irradiat          bool
# class           object
# dtype: object

# %%
y_pred = antminer.predict(X_test)
# y_pred to 0 or 1
y_pred = [1 if pred == 'True' else 0 for pred in y_pred]
y_test = [1 if pred == True else 0 for pred in y_test]

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.3438485804416404

# %%
for rule in antminer.discovered_rules:
    rule_str = " AND ".join([f"{term[0]} = {term[1]}" for term in rule[:-1]]) + f" THEN {rule[-1][1]}"
    print(rule_str)
# Out:
# MM = x THEN True
# BR = x THEN True
# TM = x AND TL = x THEN True
# TM = x THEN False
# BR = x THEN False
# TL = x AND BL = x THEN True
# BR = b THEN False
# TR = x THEN False
#  THEN False
